# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree
import re
import progressbar
import urllib.request
import multiprocessing as mp


pbar = None


def show_progress(block_num, block_size, total_size):
    global pbar
    if pbar is None:
        pbar = progressbar.ProgressBar(maxval=total_size)
        pbar.start()

    downloaded = block_num * block_size
    if downloaded < total_size:
        pbar.update(downloaded)
    else:
        pbar.finish()
        pbar = None




directory = 'https://app3.rthk.hk/special/awardpro/award11/'
website = requests.get(directory)
soup = BeautifulSoup(website.content, 'html.parser')
# id_1 = soup.find(class_ = "rollover2")
# id_2 = soup.find(class_ = "rollover3")
# print(id.text)

links = soup.find_all(href=True)
list_link=[]
for el in links:
    holder = el['href']
    if holder[0]=='t':
        list_link.append(holder)
        print(holder, len(list_link))
# Out:
# tv.php?e_id=45 1
# tv.php?e_id=37 2
# tv.php?e_id=17 3
# tv.php?e_id=38 4
# tv.php?e_id=35 5
# tv.php?e_id=44 6
# tv.php?e_id=36 7
# tv.php?e_id=34 8
# tv.php?e_id=15 9
# tv.php?e_id=14 10
# tv.php?e_id=16 11
# tv.php?e_id=42 12
# tv.php?e_id=24 13
# tv.php?e_id=30 14
# tv.php?e_id=40 15
# tv.php?e_id=25 16
# tv.php?e_id=39 17
# tv.php?e_id=7 18
# tv.php?e_id=11 19
# tv.php?e_id=29 20
# tv.php?e_id=9 21
# tv.php?e_id=43 22
# tv.php?e_id=76 23
# tv.php?e_id=28 24
# tv.php?e_id=27 25
# tv.php?e_id=33 26
# tv.php?e_id=19 27
# tv.php?e_id=41 28
# tv.php?e_id=21 29
# tv.php?e_id=22 30
# tv.php?e_id=8 31

# %%
failed_list=[]
print(len(list_link))
# Out:
# 31

# %%
def scrape(k):
#     driver = webdriver.Chrome(executable_path = chromepath)
#     driver.get(directory+link)

#     html = driver.page_source
#     soup = BeautifulSoup(html)

    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 \
                (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',\
                'Accept-Language': 'en-US, en;q=0.5'})

    website_sub = requests.get(directory+list_link[k], headers=HEADERS)
    soup = BeautifulSoup(website_sub.content, "html.parser")
#     body = soup.find_all('body')
#     print(body)
    dom = etree.HTML(str(soup))
    string = dom.xpath('/html/head/script[10]/text()')[0]
    results = re.findall('http.+?.mp4', string)
    title = soup.find('div', class_='prog_title')
    title =  title.text.replace('	',"")
    title =  title.replace('  ',"")
    print(directory+list_link[k], results, title)
    counter=0
    for result in results:
        if result != 'https://app3.rthk.hk/mp4':
            urllib.request.urlretrieve(result, title+'.mp4', show_progress) 
            counter+1
        else:
            failed_list.append(directory+list_link[k])

            
pool = mp.Pool(processes=32)

mylist = [y for y,x in enumerate(list_link)]
# print(mylist)
pool.map(scrape, mylist)

print(failed_list)
# Out:
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=45 ['https://app3.rthk.hk/podcast/media/koi/202_1201171621_48539_h.mp4']
# 沒有牆的世界：獨立宣言A Wall-less World：Declaration of Independence
#
# 8花齊放：夢遊日報Kaleidoscope of Ideas：Dream Daily(Comm. Animation)
# ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
#
# 鏗鏘集：等待黎明Hong Kong Connection：Waiting for Compassion
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=76 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
# 窮富翁大作戰Rich Mate, Poor Mate
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=24 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
# 反斗英語English Made Easy
#   0% |                                                                        |
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=28 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
# 學習無疆界：非華語學童學習中文ETV School Programme
#   0% |                                                                        |
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=25 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
# 功夫傳奇Kung Fu Quest
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=43 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
#   0% |                                                                        |
#
# 黃金歲月2010：加明叔叔Golden Age 2010：Uncle Calvin
#   0% |                                                                        |
# https://app3.rthk.hk/special/awardpro/award11/tv.php?e_id=15 ['https://app3.rthk.hk/mp4', 'https://app3.rthk.hk/mp4']
# ETV School Programme：All About Music: Tchaikovsky
# Process ForkPoolWorker-57:                                                    |
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-63:
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "<ipython-input-6-b6ef750923f9>", line 27, in scrape
#     urllib.request.urlretrieve(result, title+'.mp4', show_progress)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
# KeyboardInterrupt
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 447, in read
#     n = self.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 491, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/ato/anaconda3/lib/python3.7/ssl.py", line 1052, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/ssl.py", line 911, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "<ipython-input-6-b6ef750923f9>", line 27, in scrape
#     urllib.request.urlretrieve(result, title+'.mp4', show_progress)
#   File "<ipython-input-6-b6ef750923f9>", line 27, in scrape
#     urllib.request.urlretrieve(result, title+'.mp4', show_progress)
#   File "<ipython-input-6-b6ef750923f9>", line 27, in scrape
#     urllib.request.urlretrieve(result, title+'.mp4', show_progress)
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/ato/anaconda3/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/Users/ato/anaconda3/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
#   File "/Users/ato/anaconda3/lib/python3.7/urllib/request.py", line 276, in urlretrieve
#     block = fp.read(bs)
# KeyboardInterrupt
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 447, in read
#     n = self.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 447, in read
#     n = self.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 447, in read
#     n = self.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 491, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 491, in readinto
#     n = self.fp.readinto(b)
#   File "/Users/ato/anaconda3/lib/python3.7/http/client.py", line 491, in readinto
#     n = self.fp.readinto(b)
#
# KeyboardInterrupt
#
#   File "/Users/ato/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/ato/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/ato/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/ato/anaconda3/lib/python3.7/ssl.py", line 1052, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/ato/anaconda3/lib/python3.7/ssl.py", line 1052, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/ato/anaconda3/lib/python3.7/ssl.py", line 1052, in recv_into
#     return self.read(nbytes, buffer)
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-68:
# Traceback (most recent call last):
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/process.py", line 285, in _bootstrap
#     util._close_stdin()
#   File "/Users/ato/anaconda3/lib/python3.7/multiprocessing/util.py", line 385, in _close_stdin
#     fd = os.open(os.devnull, os.O_RDONLY)
# KeyboardInterrupt

# %%
import re

s = 'asdf=5;iwantthis123jasd'
result = re.search('asdf=5;(.*)123jasd', s)
print(result.group(1))

# %%
from urllib import request
from bs4 import BeautifulSoup as BS

url = '''https://archive.org/details/20070519_detroit2'''
#open and read page
page = urllib.request.urlopen(url)
html = page.read()
#create BeautifulSoup parse-able "soup"
soup = BS(html)
#get the src attribute from the video tag
video = soup.find_all("video")
print(video)
